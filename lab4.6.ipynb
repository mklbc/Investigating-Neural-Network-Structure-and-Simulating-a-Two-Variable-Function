# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# Function of Two Variables
def func(x):
    y = np.cos(x[0]) / x[1] - np.sin(x[0]) / x[1]**2
    z = np.sin(x[0] / 2) + y * np.sin(x[0])
    return y, z

# Collecting Dataset
x = np.linspace(12, 19, 7)
x0, x1 = np.meshgrid(x, x)
x0, x1 = x0.ravel(), x1.ravel()
X = [[x0[i], x1[i]] for i in range(len(x0))]
y, z = zip(*[func(x) for x in X])

split = int(len(X) * 0.8)
x_train, y_train, z_train = X[:split], y[:split], z[:split]
x_test, y_test, z_test = X[split:], y[split:], z[split:]

# Function to display
def visual(his):
    loss = his.history['loss']
    val_loss = his.history['val_loss']
    epochs = range(len(loss))
    
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, loss, label='Training')
    plt.plot(epochs, val_loss, label='Validation')
    plt.title('Training and Testing')
    plt.legend()
    plt.grid()
    plt.show()

# Model with 3 inner layers and 5 neurons each for Elman backprop
model_elman2 = tf.keras.models.Sequential([
    tf.keras.layers.SimpleRNN(5, activation='relu', input_shape=(1, 2)),
    tf.keras.layers.Dense(5, activation='relu'),
    tf.keras.layers.Dense(5, activation='relu'),
    tf.keras.layers.Dense(2)  # Two outputs for y and z
])

model_elman2.summary()

x_train = np.reshape(x_train, (np.shape(x_train)[0], 1, np.shape(x_train)[1]))
x_test = np.reshape(x_test, (np.shape(x_test)[0], 1, np.shape(x_test)[1]))

model_elman2.compile(
    optimizer=tf.keras.optimizers.SGD(
        learning_rate=tf.keras.optimizers.schedules.ExponentialDecay(0.001, decay_steps=75, decay_rate=0.96)
    ),
    loss='mae',
    metrics=['mae']
)

# Train the model
history_elman2 = model_elman2.fit(
    x_train, np.array([y_train, z_train]).T,  # Two outputs
    epochs=100,
    validation_data=(x_test, np.array([y_test, z_test]).T),
)

# Display learning curves
visual(history_elman2)
# Out:
# WARNING:tensorflow:From C:\Users\mehme\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\mehme\anaconda3\Lib\site-packages\keras\src\layers\rnn\simple_rnn.py:130: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 5)                 40
#
#  dense (Dense)               (None, 5)                 30
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 2)                 12
#
# =================================================================
# Total params: 112 (448.00 Byte)
# Trainable params: 112 (448.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\mehme\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\mehme\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 2/2 [==============================] - 1s 284ms/step - loss: 0.2806 - mae: 0.2806 - val_loss: 0.3443 - val_mae: 0.3443
# Epoch 2/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2651 - mae: 0.2651 - val_loss: 0.3247 - val_mae: 0.3247
# Epoch 3/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2551 - mae: 0.2551 - val_loss: 0.3086 - val_mae: 0.3086
# Epoch 4/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2484 - mae: 0.2484 - val_loss: 0.2974 - val_mae: 0.2974
# Epoch 5/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2464 - mae: 0.2464 - val_loss: 0.3051 - val_mae: 0.3051
# Epoch 6/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2453 - mae: 0.2453 - val_loss: 0.3026 - val_mae: 0.3026
# Epoch 7/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2429 - mae: 0.2429 - val_loss: 0.2983 - val_mae: 0.2983
# Epoch 8/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2404 - mae: 0.2404 - val_loss: 0.2838 - val_mae: 0.2838
# Epoch 9/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2383 - mae: 0.2383 - val_loss: 0.2950 - val_mae: 0.2950
# Epoch 10/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2380 - mae: 0.2380 - val_loss: 0.2952 - val_mae: 0.2952
# Epoch 11/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2365 - mae: 0.2365 - val_loss: 0.2826 - val_mae: 0.2826
# Epoch 12/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2342 - mae: 0.2342 - val_loss: 0.2856 - val_mae: 0.2856
# Epoch 13/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2335 - mae: 0.2335 - val_loss: 0.2926 - val_mae: 0.2926
# Epoch 14/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2329 - mae: 0.2329 - val_loss: 0.2859 - val_mae: 0.2859
# Epoch 15/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2320 - mae: 0.2320 - val_loss: 0.2808 - val_mae: 0.2808
# Epoch 16/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2320 - mae: 0.2320 - val_loss: 0.2775 - val_mae: 0.2775
# Epoch 17/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2318 - mae: 0.2318 - val_loss: 0.2771 - val_mae: 0.2771
# Epoch 18/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2315 - mae: 0.2315 - val_loss: 0.2801 - val_mae: 0.2801
# Epoch 19/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2307 - mae: 0.2307 - val_loss: 0.2829 - val_mae: 0.2829
# Epoch 20/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2299 - mae: 0.2299 - val_loss: 0.2866 - val_mae: 0.2866
# Epoch 21/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2300 - mae: 0.2300 - val_loss: 0.2896 - val_mae: 0.2896
# Epoch 22/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2303 - mae: 0.2303 - val_loss: 0.2923 - val_mae: 0.2923
# Epoch 23/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2305 - mae: 0.2305 - val_loss: 0.2837 - val_mae: 0.2837
# Epoch 24/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2288 - mae: 0.2288 - val_loss: 0.2817 - val_mae: 0.2817
# Epoch 25/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2291 - mae: 0.2291 - val_loss: 0.2698 - val_mae: 0.2698
# Epoch 26/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2309 - mae: 0.2309 - val_loss: 0.2755 - val_mae: 0.2755
# Epoch 27/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2286 - mae: 0.2286 - val_loss: 0.2758 - val_mae: 0.2758
# Epoch 28/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2284 - mae: 0.2284 - val_loss: 0.2801 - val_mae: 0.2801
# Epoch 29/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2276 - mae: 0.2276 - val_loss: 0.2772 - val_mae: 0.2772
# Epoch 30/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2278 - mae: 0.2278 - val_loss: 0.2813 - val_mae: 0.2813
# Epoch 31/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2274 - mae: 0.2274 - val_loss: 0.2724 - val_mae: 0.2724
# Epoch 32/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2278 - mae: 0.2278 - val_loss: 0.2770 - val_mae: 0.2770
# Epoch 33/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2272 - mae: 0.2272 - val_loss: 0.2748 - val_mae: 0.2748
# Epoch 34/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2279 - mae: 0.2279 - val_loss: 0.2698 - val_mae: 0.2698
# Epoch 35/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2285 - mae: 0.2285 - val_loss: 0.2711 - val_mae: 0.2711
# Epoch 36/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2277 - mae: 0.2277 - val_loss: 0.2720 - val_mae: 0.2720
# Epoch 37/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2277 - mae: 0.2277 - val_loss: 0.2706 - val_mae: 0.2706
# Epoch 38/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2276 - mae: 0.2276 - val_loss: 0.2750 - val_mae: 0.2750
# Epoch 39/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2266 - mae: 0.2266 - val_loss: 0.2748 - val_mae: 0.2748
# Epoch 40/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2262 - mae: 0.2262 - val_loss: 0.2759 - val_mae: 0.2759
# Epoch 41/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2258 - mae: 0.2258 - val_loss: 0.2756 - val_mae: 0.2756
# Epoch 42/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2258 - mae: 0.2258 - val_loss: 0.2740 - val_mae: 0.2740
# Epoch 43/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2255 - mae: 0.2255 - val_loss: 0.2742 - val_mae: 0.2742
# Epoch 44/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2249 - mae: 0.2249 - val_loss: 0.2752 - val_mae: 0.2752
# Epoch 45/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2241 - mae: 0.2241 - val_loss: 0.2748 - val_mae: 0.2748
# Epoch 46/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2236 - mae: 0.2236 - val_loss: 0.2743 - val_mae: 0.2743
# Epoch 47/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2239 - mae: 0.2239 - val_loss: 0.2704 - val_mae: 0.2704
# Epoch 48/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2254 - mae: 0.2254 - val_loss: 0.2695 - val_mae: 0.2695
# Epoch 49/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2259 - mae: 0.2259 - val_loss: 0.2696 - val_mae: 0.2696
# Epoch 50/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2249 - mae: 0.2249 - val_loss: 0.2687 - val_mae: 0.2687
# Epoch 51/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2253 - mae: 0.2253 - val_loss: 0.2726 - val_mae: 0.2726
# Epoch 52/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2237 - mae: 0.2237 - val_loss: 0.2776 - val_mae: 0.2776
# Epoch 53/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2237 - mae: 0.2237 - val_loss: 0.2763 - val_mae: 0.2763
# Epoch 54/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2228 - mae: 0.2228 - val_loss: 0.2735 - val_mae: 0.2735
# Epoch 55/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2226 - mae: 0.2226 - val_loss: 0.2698 - val_mae: 0.2698
# Epoch 56/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2228 - mae: 0.2228 - val_loss: 0.2685 - val_mae: 0.2685
# Epoch 57/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2230 - mae: 0.2230 - val_loss: 0.2679 - val_mae: 0.2679
# Epoch 58/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2228 - mae: 0.2228 - val_loss: 0.2725 - val_mae: 0.2725
# Epoch 59/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2224 - mae: 0.2224 - val_loss: 0.2738 - val_mae: 0.2738
# Epoch 60/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2227 - mae: 0.2227 - val_loss: 0.2768 - val_mae: 0.2768
# Epoch 61/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2239 - mae: 0.2239 - val_loss: 0.2681 - val_mae: 0.2681
# Epoch 62/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2222 - mae: 0.2222 - val_loss: 0.2686 - val_mae: 0.2686
# Epoch 63/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2221 - mae: 0.2221 - val_loss: 0.2674 - val_mae: 0.2674
# Epoch 64/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2222 - mae: 0.2222 - val_loss: 0.2692 - val_mae: 0.2692
# Epoch 65/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2225 - mae: 0.2225 - val_loss: 0.2661 - val_mae: 0.2661
# Epoch 66/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2230 - mae: 0.2230 - val_loss: 0.2719 - val_mae: 0.2719
# Epoch 67/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2219 - mae: 0.2219 - val_loss: 0.2729 - val_mae: 0.2729
# Epoch 68/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2223 - mae: 0.2223 - val_loss: 0.2678 - val_mae: 0.2678
# Epoch 69/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2220 - mae: 0.2220 - val_loss: 0.2657 - val_mae: 0.2657
# Epoch 70/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2223 - mae: 0.2223 - val_loss: 0.2666 - val_mae: 0.2666
# Epoch 71/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2212 - mae: 0.2212 - val_loss: 0.2679 - val_mae: 0.2679
# Epoch 72/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2219 - mae: 0.2219 - val_loss: 0.2634 - val_mae: 0.2634
# Epoch 73/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2221 - mae: 0.2221 - val_loss: 0.2643 - val_mae: 0.2643
# Epoch 74/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2219 - mae: 0.2219 - val_loss: 0.2624 - val_mae: 0.2624
# Epoch 75/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2227 - mae: 0.2227 - val_loss: 0.2616 - val_mae: 0.2616
# Epoch 76/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2225 - mae: 0.2225 - val_loss: 0.2675 - val_mae: 0.2675
# Epoch 77/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2197 - mae: 0.2197 - val_loss: 0.2690 - val_mae: 0.2690
# Epoch 78/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2201 - mae: 0.2201 - val_loss: 0.2634 - val_mae: 0.2634
# Epoch 79/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2205 - mae: 0.2205 - val_loss: 0.2646 - val_mae: 0.2646
# Epoch 80/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2196 - mae: 0.2196 - val_loss: 0.2650 - val_mae: 0.2650
# Epoch 81/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2194 - mae: 0.2194 - val_loss: 0.2668 - val_mae: 0.2668
# Epoch 82/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2191 - mae: 0.2191 - val_loss: 0.2670 - val_mae: 0.2670
# Epoch 83/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2192 - mae: 0.2192 - val_loss: 0.2660 - val_mae: 0.2660
# Epoch 84/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2196 - mae: 0.2196 - val_loss: 0.2631 - val_mae: 0.2631
# Epoch 85/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.2197 - mae: 0.2197 - val_loss: 0.2618 - val_mae: 0.2618
# Epoch 86/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2211 - mae: 0.2211 - val_loss: 0.2698 - val_mae: 0.2698
# Epoch 87/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2202 - mae: 0.2202 - val_loss: 0.2687 - val_mae: 0.2687
# Epoch 88/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2202 - mae: 0.2202 - val_loss: 0.2709 - val_mae: 0.2709
# Epoch 89/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2205 - mae: 0.2205 - val_loss: 0.2643 - val_mae: 0.2643
# Epoch 90/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2186 - mae: 0.2186 - val_loss: 0.2642 - val_mae: 0.2642
# Epoch 91/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2188 - mae: 0.2188 - val_loss: 0.2651 - val_mae: 0.2651
# Epoch 92/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2192 - mae: 0.2192 - val_loss: 0.2681 - val_mae: 0.2681
# Epoch 93/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2198 - mae: 0.2198 - val_loss: 0.2671 - val_mae: 0.2671
# Epoch 94/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2190 - mae: 0.2190 - val_loss: 0.2662 - val_mae: 0.2662
# Epoch 95/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2189 - mae: 0.2189 - val_loss: 0.2605 - val_mae: 0.2605
# Epoch 96/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2191 - mae: 0.2191 - val_loss: 0.2595 - val_mae: 0.2595
# Epoch 97/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2196 - mae: 0.2196 - val_loss: 0.2570 - val_mae: 0.2570
# Epoch 98/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2206 - mae: 0.2206 - val_loss: 0.2597 - val_mae: 0.2597
# Epoch 99/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2187 - mae: 0.2187 - val_loss: 0.2593 - val_mae: 0.2593
# Epoch 100/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2196 - mae: 0.2196 - val_loss: 0.2665 - val_mae: 0.2665
