# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# Function of Two Variables
def func(x):
    y = np.cos(x[0]) / x[1] - np.sin(x[0]) / x[1]**2
    z = np.sin(x[0] / 2) + y * np.sin(x[0])
    return y, z

# Collecting Dataset
x = np.linspace(12, 19, 7)
x0, x1 = np.meshgrid(x, x)
x0, x1 = x0.ravel(), x1.ravel()
X = [[x0[i], x1[i]] for i in range(len(x0))]
y, z = zip(*[func(x) for x in X])

split = int(len(X) * 0.8)
x_train, y_train, z_train = X[:split], y[:split], z[:split]
x_test, y_test, z_test = X[split:], y[split:], z[split:]

# Function to display
def visual(his):
    loss = his.history['loss']
    val_loss = his.history['val_loss']
    epochs = range(len(loss))
    
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, loss, label='Training')
    plt.plot(epochs, val_loss, label='Validation')
    plt.title('Training and Testing')
    plt.legend()
    plt.grid()
    plt.show()

# Model with 1 inner layer and 20 neurons
inputs = tf.keras.Input(shape=(2,))
x = tf.keras.layers.Dense(20, activation='relu')(inputs)
outputs = tf.keras.layers.Dense(2)(tf.keras.layers.concatenate([inputs, x]))  # Two outputs for y and z
model_cf1 = tf.keras.Model(inputs, outputs)

model_cf1.summary()

model_cf1.compile(
    optimizer=tf.keras.optimizers.SGD(
        learning_rate=tf.keras.optimizers.schedules.ExponentialDecay(0.001, decay_steps=75, decay_rate=0.96)
    ),
    loss='mae',
    metrics=['mae']
)

# Train the model
history_cf1 = model_cf1.fit(
    np.array(x_train), np.array([y_train, z_train]).T,  # Two outputs
    epochs=100,
    validation_data=(np.array(x_test), np.array([y_test, z_test]).T),
)

# Display learning curves
visual(history_cf1)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 2)]                  0         []
#
#  dense_6 (Dense)             (None, 20)                   60        ['input_2[0][0]']
#
#  concatenate_1 (Concatenate  (None, 22)                   0         ['input_2[0][0]',
#  )                                                                   'dense_6[0][0]']
#
#  dense_7 (Dense)             (None, 2)                    46        ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 106 (424.00 Byte)
# Trainable params: 106 (424.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/100
# 2/2 [==============================] - 1s 337ms/step - loss: 9.8506 - mae: 9.8506 - val_loss: 10.5331 - val_mae: 10.5331
# Epoch 2/100
# 2/2 [==============================] - 0s 30ms/step - loss: 8.1475 - mae: 8.1475 - val_loss: 8.6281 - val_mae: 8.6281
# Epoch 3/100
# 2/2 [==============================] - 0s 29ms/step - loss: 6.5130 - mae: 6.5130 - val_loss: 6.7371 - val_mae: 6.7371
# Epoch 4/100
# 2/2 [==============================] - 0s 31ms/step - loss: 4.8978 - mae: 4.8978 - val_loss: 4.9008 - val_mae: 4.9008
# Epoch 5/100
# 2/2 [==============================] - 0s 31ms/step - loss: 3.5046 - mae: 3.5046 - val_loss: 3.8428 - val_mae: 3.8428
# Epoch 6/100
# 2/2 [==============================] - 0s 36ms/step - loss: 2.7711 - mae: 2.7711 - val_loss: 2.7766 - val_mae: 2.7766
# Epoch 7/100
# 2/2 [==============================] - 0s 32ms/step - loss: 2.1361 - mae: 2.1361 - val_loss: 2.0229 - val_mae: 2.0229
# Epoch 8/100
# 2/2 [==============================] - 0s 34ms/step - loss: 1.5671 - mae: 1.5671 - val_loss: 1.5601 - val_mae: 1.5601
# Epoch 9/100
# 2/2 [==============================] - 0s 46ms/step - loss: 1.0268 - mae: 1.0268 - val_loss: 0.8848 - val_mae: 0.8848
# Epoch 10/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7912 - mae: 0.7912 - val_loss: 0.9965 - val_mae: 0.9965
# Epoch 11/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.7292 - mae: 0.7292 - val_loss: 0.8192 - val_mae: 0.8192
# Epoch 12/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7383 - mae: 0.7383 - val_loss: 0.8059 - val_mae: 0.8059
# Epoch 13/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.7198 - mae: 0.7198 - val_loss: 0.7611 - val_mae: 0.7611
# Epoch 14/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7244 - mae: 0.7244 - val_loss: 0.7869 - val_mae: 0.7869
# Epoch 15/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6911 - mae: 0.6911 - val_loss: 0.9918 - val_mae: 0.9918
# Epoch 16/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6815 - mae: 0.6815 - val_loss: 1.0768 - val_mae: 1.0768
# Epoch 17/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6963 - mae: 0.6963 - val_loss: 0.9332 - val_mae: 0.9332
# Epoch 18/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6662 - mae: 0.6662 - val_loss: 1.0217 - val_mae: 1.0217
# Epoch 19/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6744 - mae: 0.6744 - val_loss: 1.2359 - val_mae: 1.2359
# Epoch 20/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7209 - mae: 0.7209 - val_loss: 1.0174 - val_mae: 1.0174
# Epoch 21/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6651 - mae: 0.6651 - val_loss: 0.9795 - val_mae: 0.9795
# Epoch 22/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6250 - mae: 0.6250 - val_loss: 0.9589 - val_mae: 0.9589
# Epoch 23/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6065 - mae: 0.6065 - val_loss: 0.7713 - val_mae: 0.7713
# Epoch 24/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5787 - mae: 0.5787 - val_loss: 0.8346 - val_mae: 0.8346
# Epoch 25/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5810 - mae: 0.5810 - val_loss: 0.6306 - val_mae: 0.6306
# Epoch 26/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5880 - mae: 0.5880 - val_loss: 0.7474 - val_mae: 0.7474
# Epoch 27/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5415 - mae: 0.5415 - val_loss: 0.6439 - val_mae: 0.6439
# Epoch 28/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5544 - mae: 0.5544 - val_loss: 0.5792 - val_mae: 0.5792
# Epoch 29/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5959 - mae: 0.5959 - val_loss: 0.5931 - val_mae: 0.5931
# Epoch 30/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5277 - mae: 0.5277 - val_loss: 0.5859 - val_mae: 0.5859
# Epoch 31/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5036 - mae: 0.5036 - val_loss: 0.8376 - val_mae: 0.8376
# Epoch 32/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5013 - mae: 0.5013 - val_loss: 0.5961 - val_mae: 0.5961
# Epoch 33/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4845 - mae: 0.4845 - val_loss: 0.7814 - val_mae: 0.7814
# Epoch 34/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4913 - mae: 0.4913 - val_loss: 0.5080 - val_mae: 0.5080
# Epoch 35/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5037 - mae: 0.5037 - val_loss: 0.7316 - val_mae: 0.7316
# Epoch 36/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4761 - mae: 0.4761 - val_loss: 0.6688 - val_mae: 0.6688
# Epoch 37/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4730 - mae: 0.4730 - val_loss: 0.7656 - val_mae: 0.7656
# Epoch 38/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4860 - mae: 0.4860 - val_loss: 0.5796 - val_mae: 0.5796
# Epoch 39/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4434 - mae: 0.4434 - val_loss: 0.5893 - val_mae: 0.5893
# Epoch 40/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4404 - mae: 0.4404 - val_loss: 0.4874 - val_mae: 0.4874
# Epoch 41/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4447 - mae: 0.4447 - val_loss: 0.4455 - val_mae: 0.4455
# Epoch 42/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4893 - mae: 0.4893 - val_loss: 0.4753 - val_mae: 0.4753
# Epoch 43/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4535 - mae: 0.4535 - val_loss: 0.5882 - val_mae: 0.5882
# Epoch 44/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4342 - mae: 0.4342 - val_loss: 0.8122 - val_mae: 0.8122
# Epoch 45/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5185 - mae: 0.5185 - val_loss: 0.6094 - val_mae: 0.6094
# Epoch 46/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4654 - mae: 0.4654 - val_loss: 0.5958 - val_mae: 0.5958
# Epoch 47/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4205 - mae: 0.4205 - val_loss: 0.6181 - val_mae: 0.6181
# Epoch 48/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4207 - mae: 0.4207 - val_loss: 0.5033 - val_mae: 0.5033
# Epoch 49/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3998 - mae: 0.3998 - val_loss: 0.4091 - val_mae: 0.4091
# Epoch 50/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3975 - mae: 0.3975 - val_loss: 0.5944 - val_mae: 0.5944
# Epoch 51/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.4096 - mae: 0.4096 - val_loss: 0.5509 - val_mae: 0.5509
# Epoch 52/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3864 - mae: 0.3864 - val_loss: 0.3859 - val_mae: 0.3859
# Epoch 53/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3941 - mae: 0.3941 - val_loss: 0.5350 - val_mae: 0.5350
# Epoch 54/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.3723 - mae: 0.3723 - val_loss: 0.3969 - val_mae: 0.3969
# Epoch 55/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3566 - mae: 0.3566 - val_loss: 0.6479 - val_mae: 0.6479
# Epoch 56/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4169 - mae: 0.4169 - val_loss: 0.3558 - val_mae: 0.3558
# Epoch 57/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3630 - mae: 0.3630 - val_loss: 0.7330 - val_mae: 0.7330
# Epoch 58/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5250 - mae: 0.5250 - val_loss: 0.7432 - val_mae: 0.7432
# Epoch 59/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4943 - mae: 0.4943 - val_loss: 0.5138 - val_mae: 0.5138
# Epoch 60/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3644 - mae: 0.3644 - val_loss: 0.5293 - val_mae: 0.5293
# Epoch 61/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3805 - mae: 0.3805 - val_loss: 0.5350 - val_mae: 0.5350
# Epoch 62/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4126 - mae: 0.4126 - val_loss: 0.5662 - val_mae: 0.5662
# Epoch 63/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4180 - mae: 0.4180 - val_loss: 0.6417 - val_mae: 0.6417
# Epoch 64/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4080 - mae: 0.4080 - val_loss: 0.4144 - val_mae: 0.4144
# Epoch 65/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3385 - mae: 0.3385 - val_loss: 0.5218 - val_mae: 0.5218
# Epoch 66/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3772 - mae: 0.3772 - val_loss: 0.6323 - val_mae: 0.6323
# Epoch 67/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4820 - mae: 0.4820 - val_loss: 0.5974 - val_mae: 0.5974
# Epoch 68/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3936 - mae: 0.3936 - val_loss: 0.4996 - val_mae: 0.4996
# Epoch 69/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3588 - mae: 0.3588 - val_loss: 0.5463 - val_mae: 0.5463
# Epoch 70/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3688 - mae: 0.3688 - val_loss: 0.5116 - val_mae: 0.5116
# Epoch 71/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3422 - mae: 0.3422 - val_loss: 0.3098 - val_mae: 0.3098
# Epoch 72/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2938 - mae: 0.2938 - val_loss: 0.6763 - val_mae: 0.6763
# Epoch 73/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4682 - mae: 0.4682 - val_loss: 0.5680 - val_mae: 0.5680
# Epoch 74/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.3856 - mae: 0.3856 - val_loss: 0.3757 - val_mae: 0.3757
# Epoch 75/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3045 - mae: 0.3045 - val_loss: 0.4921 - val_mae: 0.4921
# Epoch 76/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3460 - mae: 0.3460 - val_loss: 0.6124 - val_mae: 0.6124
# Epoch 77/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4688 - mae: 0.4688 - val_loss: 0.4992 - val_mae: 0.4992
# Epoch 78/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3617 - mae: 0.3617 - val_loss: 0.4345 - val_mae: 0.4345
# Epoch 79/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3298 - mae: 0.3298 - val_loss: 0.4482 - val_mae: 0.4482
# Epoch 80/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3505 - mae: 0.3505 - val_loss: 0.5288 - val_mae: 0.5288
# Epoch 81/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.3797 - mae: 0.3797 - val_loss: 0.4246 - val_mae: 0.4246
# Epoch 82/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3587 - mae: 0.3587 - val_loss: 0.6176 - val_mae: 0.6176
# Epoch 83/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4581 - mae: 0.4581 - val_loss: 0.4830 - val_mae: 0.4830
# Epoch 84/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3489 - mae: 0.3489 - val_loss: 0.4013 - val_mae: 0.4013
# Epoch 85/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3101 - mae: 0.3101 - val_loss: 0.4810 - val_mae: 0.4810
# Epoch 86/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.3612 - mae: 0.3612 - val_loss: 0.4098 - val_mae: 0.4098
# Epoch 87/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3233 - mae: 0.3233 - val_loss: 0.5571 - val_mae: 0.5571
# Epoch 88/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4174 - mae: 0.4174 - val_loss: 0.4366 - val_mae: 0.4366
# Epoch 89/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.3403 - mae: 0.3403 - val_loss: 0.3182 - val_mae: 0.3182
# Epoch 90/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2632 - mae: 0.2632 - val_loss: 0.2895 - val_mae: 0.2895
# Epoch 91/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2546 - mae: 0.2546 - val_loss: 0.2838 - val_mae: 0.2838
# Epoch 92/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3240 - mae: 0.3240 - val_loss: 0.3644 - val_mae: 0.3644
# Epoch 93/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4104 - mae: 0.4104 - val_loss: 0.5014 - val_mae: 0.5014
# Epoch 94/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4574 - mae: 0.4574 - val_loss: 0.2879 - val_mae: 0.2879
# Epoch 95/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3239 - mae: 0.3239 - val_loss: 0.3938 - val_mae: 0.3938
# Epoch 96/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4262 - mae: 0.4262 - val_loss: 0.3573 - val_mae: 0.3573
# Epoch 97/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3836 - mae: 0.3836 - val_loss: 0.3054 - val_mae: 0.3054
# Epoch 98/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3515 - mae: 0.3515 - val_loss: 0.4683 - val_mae: 0.4683
# Epoch 99/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4573 - mae: 0.4573 - val_loss: 0.3092 - val_mae: 0.3092
# Epoch 100/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3431 - mae: 0.3431 - val_loss: 0.3281 - val_mae: 0.3281
